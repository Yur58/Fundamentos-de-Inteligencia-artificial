# %% [markdown]
# <a href="https://colab.research.google.com/github/Yur58/Fundamentos-de-Inteligencia-artificial/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**PRUEBA**

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier

data = {'Masa': [50, 80, 90, 45, 60],
        'Altura': [1.48, 1.82, 1.85, 1.55, 1.60],
        'Genero': ['m', 'h', 'h', 'm', 'm']}
punto_nuevo = {'Masa': [70],
               'Altura': [1.82]}
df = pd.DataFrame(data)
punto_nuevo = pd.DataFrame(punto_nuevo)
# sns.scatterplot(df['Masa'], df['Altura'], hue=df['sex'])
ax = plt.axes()
ax.scatter(df.loc[df['Genero'] == 'h', 'Masa'],
           df.loc[df['Genero'] == 'h', 'Altura'],
           c="red",
           label="Hombre")
ax.scatter(df.loc[df['Genero'] == 'm', 'Masa'],
           df.loc[df['Genero'] == 'm', 'Altura'],
           c="blue",
           label="Mujer")
ax.scatter(punto_nuevo['Masa'],
           punto_nuevo['Altura'],
           c="black")
plt.xlabel("Masa")
plt.ylabel("Altura")
ax.legend()
plt.show()

from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
X = df[['Masa', 'Altura']]
y = df[['Genero']]
knn.fit(X, y)
prediccion = knn.predict(punto_nuevo)
print(prediccion)
# Out:
# ['h']
# /usr/local/lib/python3.12/dist-packages/sklearn/neighbors/_classification.py:239: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %% [markdown]
# # otra manera

# %%
from sklearn.datasets import make_blobs
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import pandas as pd

# Variables para modificar
nuevo_punto = [[0, 1]]  # Coordenadas del punto a clasificar
k = 5                   # Número de vecinos

# Programa

# Crear datos sintéticos
X, y = make_blobs(centers=4, cluster_std=2, random_state=42)

# Crear dataframe
df = pd.DataFrame(X, columns=["Característica 1", "Característica 2"])
df['Target'] = y

# Crear y entrenar el modelo KNN con k=3
knn = KNeighborsClassifier(n_neighbors=k)
knn.fit(X, y)

# Clasificar con KNN
prediccion = knn.predict(nuevo_punto)[0]
vecinos = knn.kneighbors(nuevo_punto, return_distance=False)[0]

# Imprimir información
print(f"Clase predicha para el nuevo punto {nuevo_punto[0]}: Clase {prediccion}")
print(f"IDs (índices) de los 3 vecinos más cercanos: {vecinos}")

# Visualizar
plt.figure(figsize=(8, 6))

# Graficar los datos por clase
for target in df['Target'].unique():
    cluster = df[df['Target'] == target]
    plt.scatter(cluster["Característica 1"], cluster["Característica 2"], label=f'Clase {target}')

# Graficar el nuevo punto
plt.scatter(nuevo_punto[0][0], nuevo_punto[0][1], color='black', marker='X', s=100, label='Nuevo Punto')

# Graficar los vecinos más cercanos
for idx in vecinos:
    vecino = X[idx]
    plt.scatter(vecino[0], vecino[1], edgecolor='red', facecolor='none', s=200, linewidths=2)

# Atributos para el gráfico
plt.title("Clasificación con KNN (k=3)")
plt.xlabel("Característica 1")
plt.ylabel("Característica 2")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Clase predicha para el nuevo punto [0, 1]: Clase 1
# IDs (índices) de los 3 vecinos más cercanos: [26 50 13 99 49]
